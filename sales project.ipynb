# %%
import pandas as pd
data=pd.read_csv("supermarket_sales.csv")

# %%
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import analyzer
print(dir(analyzer))
# Out:
# ['SalesAnalyzer', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'pd', 'plt']

# %%
# Shape of dataset
print("shape:",data.shape)
# Out:
# shape: (1000, 17)

# %%
# Column names
data.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
# Dataset info
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
# summary starts
data.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.nunique()
# Out:
# Invoice ID                 1000
# Branch                        3
# City                          3
# Customer type                 2
# Gender                        2
# Product line                  6
# Unit price                  943
# Quantity                     10
# Tax 5%                      990
# Total                       990
# Date                         89
# Time                        506
# Payment                       3
# cogs                        990
# gross margin percentage       1
# gross income                990
# Rating                       61
# dtype: int64

# %%
data.City.unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
data[['Date']]
# Out:
#            Date
# 0    01-05-2019
# 1    03-08-2019
# 2    03-03-2019
# 3     1/27/2019
# 4    02-08-2019
# ..          ...
# 995   1/29/2019
# 996  03-02-2019
# 997  02-09-2019
# 998   2/22/2019
# 999   2/18/2019
#
# [1000 rows x 1 columns]

# %%
data['Date']
# Out:
# 0      01-05-2019
# 1      03-08-2019
# 2      03-03-2019
# 3       1/27/2019
# 4      02-08-2019
#           ...
# 995     1/29/2019
# 996    03-02-2019
# 997    02-09-2019
# 998     2/22/2019
# 999     2/18/2019
# Name: Date, Length: 1000, dtype: object

# %%
data.Rating
# Out:
# 0      9.1
# 1      9.6
# 2      7.4
# 3      8.4
# 4      5.3
#       ...
# 995    6.2
# 996    4.4
# 997    7.7
# 998    4.1
# 999    6.6
# Name: Rating, Length: 1000, dtype: float64

# %%
data.Branch.value_counts()
# Out:
# Branch
# A    340
# B    332
# C    328
# Name: count, dtype: int64

# %%
data.Branch.value_counts()*100/len(data)
# Out:
# Branch
# A    34.0
# B    33.2
# C    32.8
# Name: count, dtype: float64

# %%
data.isnull()
# Out:
#      Invoice ID  Branch   City  Customer type  Gender  Product line  \
# 0         False   False  False          False   False         False
# 1         False   False  False          False   False         False
# 2         False   False  False          False   False         False
# 3         False   False  False          False   False         False
# 4         False   False  False          False   False         False
# ..          ...     ...    ...            ...     ...           ...
# 995       False   False  False          False   False         False
# 996       False   False  False          False   False         False
# 997       False   False  False          False   False         False
# 998       False   False  False          False   False         False
# 999       False   False  False          False   False         False
#
#      Unit price  Quantity  Tax 5%  Total   Date   Time  Payment   cogs  \
# 0         False     False   False  False  False  False    False  False
# ...

# %%
data.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
import numpy as np
np.round(data.isnull().sum()*100/len(data))
# Out:
# Invoice ID                 0.0
# Branch                     0.0
# City                       0.0
# Customer type              0.0
# Gender                     0.0
# Product line               0.0
# Unit price                 0.0
# Quantity                   0.0
# Tax 5%                     0.0
# Total                      0.0
# Date                       0.0
# Time                       0.0
# Payment                    0.0
# cogs                       0.0
# gross margin percentage    0.0
# gross income               0.0
# Rating                     0.0
# dtype: float64

# %%
data.drop('Time',axis=1,inplace=True)

# %%
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
data.drop(['Invoice ID','Branch'],axis=1)
# Out:
#           City Customer type  Gender            Product line  Unit price  \
# 0       Yangon        Member  Female       Health and beauty       74.69
# 1    Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2       Yangon        Normal    Male      Home and lifestyle       46.33
# 3       Yangon        Member    Male       Health and beauty       58.22
# 4       Yangon        Normal    Male       Sports and travel       86.31
# ..         ...           ...     ...                     ...         ...
# 995  Naypyitaw        Normal    Male       Health and beauty       40.35
# 996   Mandalay        Normal  Female      Home and lifestyle       97.38
# 997     Yangon        Member    Male      Food and beverages       31.84
# 998     Yangon        Normal    Male      Home and lifestyle       65.82
# 999     Yangon        Member  Female     Fashion accessories       88.34
#
#      Quantity   Tax 5%      Total        Date      Payment    cogs  \
# ...

# %%
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
data[['Date','Rating']]
# Out:
#            Date  Rating
# 0    01-05-2019     9.1
# 1    03-08-2019     9.6
# 2    03-03-2019     7.4
# 3     1/27/2019     8.4
# 4    02-08-2019     5.3
# ..          ...     ...
# 995   1/29/2019     6.2
# 996  03-02-2019     4.4
# 997  02-09-2019     7.7
# 998   2/22/2019     4.1
# 999   2/18/2019     6.6
#
# [1000 rows x 2 columns]

# %%
data['profit']=data['Total']-data['cogs']

# %%
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# Convert 'Data' column to datetime safely (auto-detect format)
data['Date']=pd.to_datetime(data['Date'],errors='coerce') #converts invalid to

# %%
data
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
# optional: check if any date conversion failed
print('Missing dates:',data['Date'].isnull().sum())
# Out:
# Missing dates: 587

# %%
# Extract month ig dates are successfully parsed.
data['Month']=data['Date'].dt.month_name()

# %%
data['Month']
# Out:
# 0       January
# 1         March
# 2         March
# 3           NaN
# 4      February
#          ...
# 995         NaN
# 996       March
# 997    February
# 998         NaN
# 999         NaN
# Name: Month, Length: 1000, dtype: object

# %%
# Extract day dates are successfully parsed.
data['Day']=data['Date'].dt.day_name()

# %%
data['Day']
# Out:
# 0      Saturday
# 1        Friday
# 2        Sunday
# 3           NaN
# 4        Friday
#          ...
# 995         NaN
# 996    Saturday
# 997    Saturday
# 998         NaN
# 999         NaN
# Name: Day, Length: 1000, dtype: object

# %%
# Show result
print(data[['Date','Month','Day']].head())
# Out:
#         Date     Month       Day
# 0 2019-01-05   January  Saturday
# 1 2019-03-08     March    Friday
# 2 2019-03-03     March    Sunday
# 3        NaT       NaN       NaN
# 4 2019-02-08  February    Friday

# %%
data.groupby('Day')['Total'].sum().plot(kind='bar')
# Out:
# <Axes: xlabel='Day'>

# %%
top_city=data.groupby('City')['Total'].sum().sort_values(ascending=False)
print(top_city)
# Out:
# City
# Naypyitaw    110568.7065
# Yangon       106200.3705
# Mandalay     106197.6720
# Name: Total, dtype: float64

# %%
top_product=data.groupby('Product line')['Total'].sum().sort_values(ascending=False)
print(top_product)
# Out:
# Product line
# Food and beverages        56144.8440
# Sports and travel         55122.8265
# Electronic accessories    54337.5315
# Fashion accessories       54305.8950
# Home and lifestyle        53861.9130
# Health and beauty         49193.7390
# Name: Total, dtype: float64

# %%
top_gender=data.groupby('Gender')['Total'].sum().sort_values(ascending=False)
print(top_gender)
# Out:
# Gender
# Female    167882.925
# Male      155083.824
# Name: Total, dtype: float64

# %%
data['Date']=pd.to_datetime(data['Date']) #Safe conversion
data['Month']=data['Date'].dt.month_name()

monthly_sales=data.groupby('Month')['Total'].sum().sort_values(ascending=False)
print(monthly_sales)
# Out:
# Month
# March       49105.4865
# February    46696.3875
# January     39553.3845
# Name: Total, dtype: float64

# %%
data['Day']=data['Date'].dt.day_name()
top_day=data.groupby('Day')['Total'].sum().sort_values(ascending=False)
print(top_day)
# Out:
# Day
# Saturday     30168.6420
# Tuesday      25977.4620
# Sunday       20239.5585
# Friday       17027.5980
# Monday       16671.5850
# Thursday     14305.5465
# Wednesday    10964.8665
# Name: Total, dtype: float64

# %%
payment=data.groupby('Payment')['Total'].sum().sort_values(ascending=False)
print(payment)
# Out:
# Payment
# Cash           112206.570
# Ewallet        109993.107
# Credit card    100767.072
# Name: Total, dtype: float64

# %%
best_city=top_city.idxmax()
print("Best Performing City:",best_city)

best_product=top_product.idxmax()
print("Best Product Line",best_product)
# Out:
# Best Performing City: Naypyitaw
# Best Product Line Food and beverages

# %%
data['Profit']=data['Total']-data['cogs']
top_profit_product=data.groupby('Product line')['Profit'].sum().sort_values(ascending=False)
print(top_profit_product)
# Out:
# Product line
# Food and beverages        2673.5640
# Sports and travel         2624.8965
# Electronic accessories    2587.5015
# Fashion accessories       2585.9950
# Home and lifestyle        2564.8530
# Health and beauty         2342.5590
# Name: Profit, dtype: float64

# %%
data.groupby('Day')['Total'].sum().plot(kind='bar',color='green',figsize=(7,4))
plt.title('Total sales by Day')
plt.ylabel('Total sales')
plt.xlabel('Day')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()
